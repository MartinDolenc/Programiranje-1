# %%
import pandas as pd

# %%
igre = pd.read_csv('ign.csv', encoding = 'latin1')

# %%
igre
# Out:
#        Unnamed: 0      X score_phrase  \
# 0               1      0      Amazing
# 1               2      1      Amazing
# 2               3      2        Great
# 3               4      3        Great
# 4               5      4        Great
# 5               6      5         Good
# 6               7      6        Awful
# 7               8      7      Amazing
# 8               9      8        Awful
# 9              10      9         Good
# 10             11     10         Good
# 11             12     11         Good
# 12             14     13      Amazing
# 13             15     14      Amazing
# 14             16     15         Okay
# 15             17     16         Okay
# 16             18     17        Great
# 17             19     18     Mediocre
# 18             20     19         Good
# 19             21     20         Good
# 20             22     21         Good
# 21             23     22         Good
# 22             24     23         Good
# ...

# %%
igre[igre['release_year'] > 1995].groupby('release_year').mean()['score'].plot()

# %%
# %matplotlib inline

# %%
igre[igre['release_year'] > 1995].groupby('release_year').size().plot()

# %%
igre[igre['release_year'] > 1995].groupby('genre').mean()['score'].sort_values().plot.bar()

# %%
igre[igre['score'] == 10].sort_values('release_year')
# Out:
#        Unnamed: 0      X score_phrase  \
# 1054         1059   1058  Masterpiece
# 1668         1673   1672  Masterpiece
# 1588         1593   1592  Masterpiece
# 1457         1462   1461  Masterpiece
# 1453         1458   1457  Masterpiece
# 1430         1435   1434  Masterpiece
# 1790         1795   1794  Masterpiece
# 1359         1364   1363  Masterpiece
# 1350         1355   1354  Masterpiece
# 1285         1290   1289  Masterpiece
# 1283         1288   1287  Masterpiece
# 1404         1409   1408  Masterpiece
# 2612         2617   2616  Masterpiece
# 2170         2175   2174  Masterpiece
# 2563         2568   2567  Masterpiece
# 1923         1928   1927  Masterpiece
# 2004         2009   2008  Masterpiece
# 3075         3080   3079  Masterpiece
# 3076         3081   3080  Masterpiece
# 3232         3237   3236  Masterpiece
# 8636         8641   8640  Masterpiece
# 8977         8982   8981  Masterpiece
# 11022       11032  11031  Masterpiece
# ...

# %%
igre[igre['platform'] == 'PC'].groupby('release_year').mean()['score'].plot()

# %%
igre[igre['platform'] == 'PlayStation 4'].groupby('release_year').mean()['score'].plot()

# %%
igre[igre['platform'] == 'PlayStation 3'].groupby('release_year').mean()['score'].plot()

# %%
igre[igre['platform'] == 'Xbox One'].groupby('release_year').mean()['score'].plot()

# %%
igre[igre['platform'] == 'Xbox 360'].groupby('release_year').mean()['score'].plot()

# %%
igre[(igre['score'] == 10) & (igre['platform'] == 'PC')].sort_values('release_year')
# Out:
#        Unnamed: 0      X score_phrase                                 title  \
# 18031       18068  18067  Masterpiece                    Grand Theft Auto V
# 18398       18435  18434  Masterpiece  Metal Gear Solid V: The Phantom Pain
# 18317       18354  18353  Masterpiece                           The Witness
# 18381       18418  18417  Masterpiece                             Undertale
# 18588       18625  18624  Masterpiece                                Inside
#
#                                          url platform  score      genre  \
# 18031     /games/grand-theft-auto-v/pc-20593       PC   10.0     Action
# 18398  /games/metal-gear-solid-5/pc-20023125       PC   10.0     Action
# 18317            /games/the-witness/pc-23509       PC   10.0     Puzzle
# 18381           /games/undertale/pc-20003810       PC   10.0        RPG
# 18588     /games/inside-playdead/pc-20055740       PC   10.0  Adventure
#
#           genre2 editors_choice  release_year  release_month  release_day
# ...

# %%
igre[(igre['score'] == 10) & (igre['platform'] == 'PlayStation 4')].sort_values('release_year')
# Out:
#        Unnamed: 0      X score_phrase                                 title  \
# 17798       17835  17834  Masterpiece            The Last of Us: Remastered
# 17962       17999  17998  Masterpiece                    Grand Theft Auto V
# 18397       18434  18433  Masterpiece  Metal Gear Solid V: The Phantom Pain
# 18316       18353  18352  Masterpiece                           The Witness
# 18475       18512  18511  Masterpiece                                Inside
#
#                                           url       platform  score  \
# 17798      /games/the-last-of-us/ps4-20015419  PlayStation 4   10.0
# 17962  /games/grand-theft-auto-v/ps4-20019830  PlayStation 4   10.0
# 18397    /games/metal-gear-solid-5/ps4-149843  PlayStation 4   10.0
# 18316            /games/the-witness/ps4-23512  PlayStation 4   10.0
# 18475     /games/inside-playdead/ps4-20056859  PlayStation 4   10.0
#
#            genre     genre2 editors_choice  release_year  release_month  \
# ...

# %%
igre[(igre['score'] == 10) & (igre['platform'] == 'PlayStation 3')].sort_values('release_year')
# Out:
#        Unnamed: 0      X score_phrase  \
# 10829       10839  10838  Masterpiece
# 10892       10902  10901  Masterpiece
# 11022       11032  11031  Masterpiece
# 11112       11122  11121  Masterpiece
# 15111       15136  15135  Masterpiece
# 15296       15322  15321  Masterpiece
# 16246       16280  16279  Masterpiece
# 17094       17129  17128  Masterpiece
# 17129       17164  17163  Masterpiece
#
#                                                    title  \
# 10829              Grand Theft Auto IV (Special Edition)
# 10892                                Grand Theft Auto IV
# 11022           Metal Gear Solid 4: Guns of the Patriots
# 11112  Metal Gear Solid 4: Guns of the Patriots (Limi...
# 15111                    Pac-Man Championship Edition DX
# 15296            Red Dead Redemption -- Undead Nightmare
# 16246                     Uncharted 3: Drake's Deception
# 17094                                     The Last of Us
# 17129                                 Grand Theft Auto V
#
# ...

# %%
igre[(igre['score'] == 10) & (igre['platform'] == 'Xbox One')].sort_values('release_year')
# Out:
#        Unnamed: 0      X score_phrase                                 title  \
# 17963       18000  17999  Masterpiece                    Grand Theft Auto V
# 18396       18433  18432  Masterpiece  Metal Gear Solid V: The Phantom Pain
# 18318       18355  18354  Masterpiece                           The Witness
# 18587       18624  18623  Masterpiece                                Inside
#
#                                                url  platform  score  \
# 17963  /games/grand-theft-auto-v/xbox-one-20019839  Xbox One   10.0
# 18396  /games/metal-gear-solid-5/xbox-one-20000541  Xbox One   10.0
# 18318         /games/the-witness/xbox-one-20057751  Xbox One   10.0
# 18587       /games/inside-playdead/xbox-one-121435  Xbox One   10.0
#
#            genre     genre2 editors_choice  release_year  release_month  \
# 17963     Action  Adventure              Y          2014             11
# 18396     Action        NaN              Y          2015              8
# ...

# %%
igre[(igre['score'] == 10) & (igre['platform'] == 'Xbox 360')].sort_values('release_year')
# Out:
#        Unnamed: 0      X score_phrase  \
# 10827       10837  10836  Masterpiece
# 10865       10875  10874  Masterpiece
# 15213       15238  15237  Masterpiece
# 15295       15321  15320  Masterpiece
# 17130       17165  17164  Masterpiece
#
#                                          title  \
# 10827    Grand Theft Auto IV (Special Edition)
# 10865                      Grand Theft Auto IV
# 15213          Pac-Man Championship Edition DX
# 15295  Red Dead Redemption -- Undead Nightmare
# 17130                       Grand Theft Auto V
#
#                                                      url  platform  score  \
# 10827         /games/grand-theft-auto-iv/xbox-360-907969  Xbox 360   10.0
# 10865         /games/grand-theft-auto-iv/xbox-360-827005  Xbox 360   10.0
# 15213  /games/pac-man-championship-edition-dx/xbox-36...  Xbox 360   10.0
# 15295  /games/red-dead-redemption-undead-nightmare/xb...  Xbox 360   10.0
# ...
